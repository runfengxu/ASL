# %%
import scipy.io as scio
import os

# %%
files1= os.listdir('sign')
for file1 in files1:
    files2 = os.listdir('sign/'+file1)
    for file2 in files2:
        d = scio.loadmat('sign/'+file1+'/'+file2)
        if len(d['special'])>0:
            print(file1,file2)
# Out:
# 1-Introduction-SD.mov 1043to1247
# 1-Introduction-SD.mov 107to273
# 1-Introduction-SD.mov 1248to1448
# 1-Introduction-SD.mov 1449to1589
# 1-Introduction-SD.mov 1896to1997
# 1-Introduction-SD.mov 2249to2581
# 1-Introduction-SD.mov 2582to2836
# 1-Introduction-SD.mov 274to559
# 1-Introduction-SD.mov 2837to3041
# 1-Introduction-SD.mov 3046to3203
# 1-Introduction-SD.mov 3204to3293
# 1-Introduction-SD.mov 3370to3589
# 1-Introduction-SD.mov 3949to4089
# 1-Introduction-SD.mov 721to830
# 1-Introduction-SD.mov 950to1038
# 2011-12-01_0043-cam2-for-ss3.mp4 1358to1478
# 2011-12-01_0043-cam2-for-ss3.mp4 1570to1717
# 2011-12-01_0043-cam2-for-ss3.mp4 189to299
# 2011-12-01_0043-cam2-for-ss3.mp4 2085to2173
# 2011-12-01_0043-cam2-for-ss3.mp4 2479to2583
# 2011-12-01_0043-cam2-for-ss3.mp4 2685to2795
# 2011-12-01_0043-cam2-for-ss3.mp4 2886to2954
# 2011-12-01_0043-cam2-for-ss3.mp4 3045to3126
# 2011-12-01_0043-cam2-for-ss3.mp4 3273to3370
# 2011-12-01_0043-cam2-for-ss3.mp4 3461to3577
# ...

# %%
d = scio.loadmat('dataset/2011-12-01_0043-cam2-for-ss3_6to98.mat')

# %%
d['path']
# Out:
# array(['frames/2011-12-01_0043-cam2-for-ss3/frame9.jpg       ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame10.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame11.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame12.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame13.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame14.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame15.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame16.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame17.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame18.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame19.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame20.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame21.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame22.jpg      ',
#        'frames/2011-12-01_0043-cam2-for-ss3/frame23.jpg      ',
# ...
